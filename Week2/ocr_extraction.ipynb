# %%
import sys
# !{sys.executable} -m pip install easyocr
# Out:
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (2.7.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (0.22.1)
# Collecting opencv-python-headless (from easyocr)
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scipy in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (1.15.3)
# Requirement already satisfied: numpy in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (2.2.4)
# Requirement already satisfied: Pillow in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (11.2.1)
# Collecting scikit-image (from easyocr)
#   Downloading scikit_image-0.26.0-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.6.7-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: PyYAML in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from easyocr) (6.0.2)
# Collecting Shapely (from easyocr)
#   Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.4.0-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# Collecting ninja (from easyocr)
#   Downloading ninja-1.13.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (2025.3.0)
# Requirement already satisfied: setuptools in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from torch->easyocr) (80.7.1)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->easyocr)
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr)
#   Downloading tifffile-2025.12.20-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging>=21 in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from scikit-image->easyocr) (25.0)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\srush\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch->easyocr) (3.0.2)
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 2.3 MB/s eta 0:00:02
#    --------------------- ------------------ 1.6/2.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------
MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.9 MB/s eta 0:00:00
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2025.12.20-py3-none-any.whl (232 kB)
# Installing collected packages: python-bidi, tifffile, Shapely, pyclipper, opencv-python-headless, ninja, lazy-loader, imageio, scikit-image, easyocr
# Successfully installed Shapely-2.1.2 easyocr-1.7.2 imageio-2.37.2 lazy-loader-0.4 ninja-1.13.0 opencv-python-headless-4.12.0.88 pyclipper-1.4.0 python-bidi-0.6.7 scikit-image-0.26.0 tifffile-2025.12.20
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\srush\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import easyocr
from PIL import Image, ImageDraw

reader = easyocr.Reader(['en'], gpu=True)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
image_paths = [
    "meme1.jpg",
    "meme2.jpg",
    "meme3.jpg"
]

for path in image_paths:
    print(f"\nText extracted from {path}:")
    results = reader.readtext(path)
    for bbox, text, confidence in results:
        print(text)
# Out:
# Text extracted from meme1.jpg:
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Wenvoustartvour assignmentan hour
# pefore te deadline andvou end up
# getinganA
#
# Text extracted from meme2.jpg:
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Food gives You energy'
# Me, after eating:
#
# Text extracted from meme3.jpg:
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# me panicking over due dates and then
# panicking over lack of time and then
# panicking because i'm panicking

# %%
for path in image_paths:
    print(f"\nFiltered text from {path}:")
    results = reader.readtext(path)
    for bbox, text, confidence in results:
        if confidence > 0.5:
            print(text)
# Out:
# Filtered text from meme1.jpg:
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Wenvoustartvour assignmentan hour
# pefore te deadline andvou end up
# getinganA
#
# Filtered text from meme2.jpg:
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Food gives You energy'
# Me, after eating:
#
# Filtered text from meme3.jpg:
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# me panicking over due dates and then
# panicking over lack of time and then
# panicking because i'm panicking

# %%
for path in image_paths:
    image = Image.open(path).convert("RGB")
    draw = ImageDraw.Draw(image)

    results = reader.readtext(path)
    for bbox, text, confidence in results:
        if confidence > 0.5:
            top_left = tuple(bbox[0])
            bottom_right = tuple(bbox[2])
            draw.rectangle([top_left, bottom_right], outline="red", width=3)

    image.show()
# Out:
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# C:\Users\srush\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
